# %% [markdown]
# # South America
#
# Analysis and visualisation of data about South America.
#
# ## Imports

# %%
import pandas as pd
import altair as alt

# %% [markdown]
# ## Data Sourcing

# %%
sa = pd.read_csv("https://sigma-resources-public.s3.eu-west-2.amazonaws.com/datasets/south_america_data.csv")

# %%
sa.head(2)
# Out:
#    year       name  life_expectancy_female  life_expectancy_male  birth_rate  \
# 0  2000  Argentina                   77.22                 70.58       19.37
# 1  2000     Brazil                   73.43                 66.26       19.84
#
#    population
# 0    37070774
# 1   175873720

# %% [markdown]
# ## Data Exploration

# %%
sa["name"].unique()
# Out:
# array(['Argentina', 'Brazil', 'Bolivia', 'Chile', 'Colombia', 'Ecuador',
#        'Guyana', 'Paraguay', 'Peru', 'Suriname', 'Venezuela, RB',
#        'Uruguay'], dtype=object)

# %%
sa.tail()
# Out:
#      year           name  life_expectancy_female  life_expectancy_male  \
# 175  2021       Paraguay                   73.39                 67.43
# 176  2021           Peru                   74.75                 70.12
# 177  2021       Suriname                   73.55                 67.21
# 178  2021  Venezuela, RB                   75.21                 66.26
# 179  2021        Uruguay                   79.26                 71.65
#
#      birth_rate  population
# 175       20.63     6703799
# 176       17.62    33715471
# 177       18.15      612985
# 178       15.88    28199867
# 179       10.47     3426260

# %% [markdown]
# ### Filtering
#
# 1. Check every row against a condition (producing a column of True/False values)
# 2. Use the produced column as a filter

# %%
bool_filter = sa["name"] == "Argentina"

# %%
sa[bool_filter]
# Out:
#      year       name  life_expectancy_female  life_expectancy_male  \
# 0    2000  Argentina                   77.22                 70.58
# 12   2001  Argentina                   77.59                 70.75
# 24   2002  Argentina                   78.08                 70.75
# 36   2003  Argentina                   77.28                 70.83
# 48   2004  Argentina                   78.10                 71.53
# 60   2005  Argentina                   78.53                 71.69
# 72   2006  Argentina                   78.72                 72.07
# 84   2014  Argentina                   80.00                 73.42
# 96   2015  Argentina                   80.19                 73.29
# 108  2016  Argentina                   79.67                 72.93
# 120  2017  Argentina                   80.08                 73.53
# 132  2018  Argentina                   80.33                 73.63
# 144  2019  Argentina                   80.68                 73.86
# 156  2020  Argentina                   79.28                 72.55
# 168  2021  Argentina                   78.65                 72.18
#
#      birth_rate  population
# 0         19.37    37070774
# 12        18.98    37480493
# 24        18.76    37885028
# 36        18.45    38278164
# 48        18.35    38668796
# 60        18.35    39070501
# 72        18.19    39476851
# 84        17.50    42669500
# 96        17.35    43131966
# 108       16.82    43590368
# 120       16.21    44044811
# 132       15.19    44494502
# 144       14.78    44938712
# 156       14.12    45376763
# 168       13.90    45808747

# %%
sa[sa["name"] == "Argentina"]
# Out:
#      year       name  life_expectancy_female  life_expectancy_male  \
# 0    2000  Argentina                   77.22                 70.58
# 12   2001  Argentina                   77.59                 70.75
# 24   2002  Argentina                   78.08                 70.75
# 36   2003  Argentina                   77.28                 70.83
# 48   2004  Argentina                   78.10                 71.53
# 60   2005  Argentina                   78.53                 71.69
# 72   2006  Argentina                   78.72                 72.07
# 84   2014  Argentina                   80.00                 73.42
# 96   2015  Argentina                   80.19                 73.29
# 108  2016  Argentina                   79.67                 72.93
# 120  2017  Argentina                   80.08                 73.53
# 132  2018  Argentina                   80.33                 73.63
# 144  2019  Argentina                   80.68                 73.86
# 156  2020  Argentina                   79.28                 72.55
# 168  2021  Argentina                   78.65                 72.18
#
#      birth_rate  population
# 0         19.37    37070774
# 12        18.98    37480493
# 24        18.76    37885028
# 36        18.45    38278164
# 48        18.35    38668796
# 60        18.35    39070501
# 72        18.19    39476851
# 84        17.50    42669500
# 96        17.35    43131966
# 108       16.82    43590368
# 120       16.21    44044811
# 132       15.19    44494502
# 144       14.78    44938712
# 156       14.12    45376763
# 168       13.90    45808747

# %%
sa.head()
# Out:
#    year       name  life_expectancy_female  life_expectancy_male  birth_rate  \
# 0  2000  Argentina                   77.22                 70.58       19.37
# 1  2000     Brazil                   73.43                 66.26       19.84
# 2  2000    Bolivia                   64.39                 60.42       29.72
# 3  2000      Chile                   79.98                 73.71       15.96
# 4  2000   Colombia                   75.54                 67.31       22.11
#
#    population
# 0    37070774
# 1   175873720
# 2     8592656
# 3    15351799
# 4    39215135

# %%
# Filter for all countries 

sa[sa["year"] < 2006]
# Out:
#     year           name  life_expectancy_female  life_expectancy_male  \
# 0   2000      Argentina                   77.22                 70.58
# 1   2000         Brazil                   73.43                 66.26
# 2   2000        Bolivia                   64.39                 60.42
# 3   2000          Chile                   79.98                 73.71
# 4   2000       Colombia                   75.54                 67.31
# ..   ...            ...                     ...                   ...
# 67  2005       Paraguay                   73.72                 67.61
# 68  2005           Peru                   75.02                 71.05
# 69  2005       Suriname                   70.42                 63.98
# 70  2005  Venezuela, RB                   76.67                 69.14
# 71  2005        Uruguay                   80.38                 71.91
#
#     birth_rate  population
# 0        19.37    37070774
# 1        19.84   175873720
# 2        29.72     8592656
# 3        15.96    15351799
# 4        22.11    39215135
# ..         ...         ...
# 67       24.05     5476878
# 68       22.33    28147267
# 69       22.27      516220
# 70       22.33    26668785
# 71       15.10     3317665
#
# [72 rows x 6 columns]

# %% [markdown]
# ## Challenge
#
# 1. Create a variable called `y2018` that contains just rows from 2018
# 2. Create a variable called `cBrazil` that contains just Brazil rows

# %%
y2018 = sa[sa["year"] == 2018]
cBrazil = sa[sa["name"] == "Brazil"]

# %%
cBrazil["birth_rate"].min()
# Out:
# np.float64(12.88)

# %%
cBrazil.sort_values(by="life_expectancy_female", ascending=False).head(3)
# Out:
#      year    name  life_expectancy_female  life_expectancy_male  birth_rate  \
# 145  2019  Brazil                   78.47                 72.20       13.63
# 133  2018  Brazil                   78.27                 71.96       14.13
# 121  2017  Brazil                   78.03                 71.64       14.16
#
#      population
# 145   211782878
# 133   210166592
# 121   208504960

# %% [markdown]
# ## Challenge
#
# What's the integer difference between the lowest male life expectancy and the highest female life expectancy ever across all of South America?

# %%
sa["life_expectancy_female"].max() - sa["life_expectancy_male"].min()
# Out:
# np.float64(22.289999999999992)

# %%
sa["life_expectancy_female"].max() - sa["life_expectancy_male"].min()
# Out:
# np.float64(22.289999999999992)

# %%
sa["life_expectancy_female"].sort_values(ascending=False)
# Out:
# 147    82.71
# 123    82.60
# 111    82.57
# 135    82.53
# 99     82.38
#        ...
# 50     66.24
# 38     65.98
# 26     65.56
# 14     64.99
# 2      64.39
# Name: life_expectancy_female, Length: 180, dtype: float64

# %% [markdown]
# ## Visualisation
#
# 1. Make a chart
# 2. Feed the chart the dataset
# 3. State what kind of chart it is
# 4. Explain how the different columns will be mapped onto the chart

# %%
alt.Chart(y2018).mark_bar().encode(
    x = 'name',
    y = 'population'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Challenge
#
# - Make a scatterplot (`mark_point()`) of `birth_rate` and `population` for 2108

# %%
alt.Chart(y2018).mark_point().encode(
    y="birth_rate",
    x="population"
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(y2018).mark_point().encode(
    x=alt.X("birth_rate").sort("-y"),
    y="population",
    color="name"
)
# Out:
# alt.Chart(...)
