# %% [markdown]
# # Sharks
#
# This notebook cleans and processes a dataset of shark attack data.
#
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Data sourcing

# %%
sharks = pd.read_excel("https://www.sharkattackfile.net/spreadsheets/GSAF5.xls")

# %%
sharks.head()
# Out:
#                   Date    Year        Type    Country                State  \
# 0  2025-04-19 00:00:00  2025.0  Unprovoked   Maldives  Kulhudhuffushi City
# 1  2025-04-12 00:00:00  2025.0  Unprovoked        USA              Florida
# 2  2025-03-26 00:00:00  2025.0  Unprovoked  Australia                   WA
# 3  2025-03-10 00:00:00  2025.0  Unprovoked  Australia                   WA
# 4  2025-03-07 00:00:00  2025.0  Unprovoked  Australia                  NSW
#
#                                             Location     Activity  \
# 0                                   Haa Dhaalu atoll   snorkeling
# 1  Everglades National Park Flamingo Lodge Highwa...  Undisclosed
# 2          Sandtrax Port Beach North Fremantle Perth     Swimming
# 3                                Duke of Orleans Bay      Surfing
# 4                 Gunyah beach Bundeena Port Hacking     Swimming
#
#                    Name Sex  Age  ...           Species   \
# 0          Unknown Male   M   30  ...         Not stated
# 1          Unknown Male   M    ?  ...         Not stated
# 2          Unknown Male   M  30+  ...   1.5m Tiger shark
# 3  Steven Jeffrey Payne   M   37  ...  Great White Shark
# 4        Mangyong Zhang  F    56  ...         Bull shark
#
#                                               Source  pdf href formula href  \
# 0   Todd Smith: The edition: https://en.sun.mv/96031  NaN          NaN  NaN
# 1  Kevin McMurray Trackingsharks.com: Florida New...  NaN          NaN  NaN
# 2  Kevin McMurray Trackingsharks.com: www.surfer....  NaN          NaN  NaN
# 3                                          Bob Myatt  NaN          NaN  NaN
# 4                                          Bob Myatt  NaN          NaN  NaN
#
#   Case Number Case Number.1 original order Unnamed: 21 Unnamed: 22
# 0         NaN           NaN            NaN         NaN         NaN
# 1         NaN           NaN            NaN         NaN         NaN
# 2         NaN           NaN            NaN         NaN         NaN
# 3         NaN           NaN            NaN         NaN         NaN
# 4         NaN           NaN            NaN         NaN         NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Data Exploration
#
# ### Pandas has opinions
#
# - You shouldn't scroll through large amounts of data
# - You are a reckless fool and should only edit copies
# - Empty values are a problem

# %%
sharks[["Activity", "Age", "Name"]].sample()
# Out:
#      Activity              Age                 Name
# 5088  Fishing  MAKE LINE GREEN  14-foot boat Sintra

# %%
sharks["Sex"].unique()
# Out:
# array(['M', 'F ', 'F', 'M ', nan, ' M', 'm', 'lli', 'M x 2', 'N', '.'],
#       dtype=object)

# %%
sharks["Sex"].value_counts()
# Out:
# Sex
# M        5624
# F         798
# M           3
# N           2
# F           1
#  M          1
# m           1
# lli         1
# M x 2       1
# .           1
# Name: count, dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
sharks.columns = sharks.columns.str.lower()

# %%
sharks["sex"] = sharks["sex"].replace("F ", "F")

# %%
sharks = sharks.drop(columns="pdf")

# %%
sharks.head()
# Out:
#                   date    year        type    country                state  \
# 0  2025-04-19 00:00:00  2025.0  Unprovoked   Maldives  Kulhudhuffushi City
# 1  2025-04-12 00:00:00  2025.0  Unprovoked        USA              Florida
# 2  2025-03-26 00:00:00  2025.0  Unprovoked  Australia                   WA
# 3  2025-03-10 00:00:00  2025.0  Unprovoked  Australia                   WA
# 4  2025-03-07 00:00:00  2025.0  Unprovoked  Australia                  NSW
#
#                                             location     activity  \
# 0                                   Haa Dhaalu atoll   snorkeling
# 1  Everglades National Park Flamingo Lodge Highwa...  Undisclosed
# 2          Sandtrax Port Beach North Fremantle Perth     Swimming
# 3                                Duke of Orleans Bay      Surfing
# 4                 Gunyah beach Bundeena Port Hacking     Swimming
#
#                    name sex  age  ...        time           species   \
# 0          Unknown Male   M   30  ...  Not stated         Not stated
# 1          Unknown Male   M    ?  ...     1500hrs         Not stated
# 2          Unknown Male   M  30+  ...     1430hrs   1.5m Tiger shark
# 3  Steven Jeffrey Payne   M   37  ...    1210 hrs  Great White Shark
# 4        Mangyong Zhang   F   56  ...     1340hrs         Bull shark
#
#                                               source href formula href  \
# 0   Todd Smith: The edition: https://en.sun.mv/96031          NaN  NaN
# 1  Kevin McMurray Trackingsharks.com: Florida New...          NaN  NaN
# 2  Kevin McMurray Trackingsharks.com: www.surfer....          NaN  NaN
# 3                                          Bob Myatt          NaN  NaN
# 4                                          Bob Myatt          NaN  NaN
#
#   case number case number.1 original order unnamed: 21  unnamed: 22
# 0         NaN           NaN            NaN         NaN          NaN
# 1         NaN           NaN            NaN         NaN          NaN
# 2         NaN           NaN            NaN         NaN          NaN
# 3         NaN           NaN            NaN         NaN          NaN
# 4         NaN           NaN            NaN         NaN          NaN
#
# [5 rows x 22 columns]

# %%
sharks["year"].unique()
# Out:
# array([2025., 2024., 2026., 2023., 2022., 2021., 2020., 2019., 2018.,
#        2017.,   nan, 2016., 2015., 2014., 2013., 2012., 2011., 2010.,
#        2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002., 2001.,
#        2000., 1999., 1998., 1997., 1996., 1995., 1984., 1994., 1993.,
#        1992., 1991., 1990., 1989., 1969., 1988., 1987., 1986., 1985.,
#        1983., 1982., 1981., 1980., 1979., 1978., 1977., 1976., 1975.,
#        1974., 1973., 1972., 1971., 1970., 1968., 1967., 1966., 1965.,
#        1964., 1963., 1962., 1961., 1960., 1959., 1958., 1957., 1956.,
#        1955., 1954., 1953., 1952., 1951., 1950., 1949., 1948., 1848.,
#        1947., 1946., 1945., 1944., 1943., 1942., 1941., 1940., 1939.,
#        1938., 1937., 1936., 1935., 1934., 1933., 1932., 1931., 1930.,
#        1929., 1928., 1927., 1926., 1925., 1924., 1923., 1922., 1921.,
#        1920., 1919., 1918., 1917., 1916., 1915., 1914., 1913., 1912.,
#        1911., 1910., 1909., 1908., 1907., 1906., 1905., 1904., 1903.,
#        1902., 1901., 1900., 1899., 1898., 1897., 1896., 1895., 1894.,
#        1893., 1892., 1891., 1890., 1889., 1888., 1887., 1886., 1885.,
#        1884., 1883., 1882., 1881., 1880., 1879., 1878., 1877., 1876.,
#        1875., 1874., 1873., 1872., 1871., 1870., 1869., 1868., 1867.,
#        1866., 1865., 1864., 1863., 1862., 1861., 1860., 1859., 1858.,
#        1857., 1856., 1855., 1853., 1852., 1851., 1850., 1849., 1847.,
#        1846., 1845., 1844., 1842., 1841., 1840., 1839., 1837., 1836.,
#        1835., 1834., 1832., 1831., 1830., 1829., 1828., 1827., 1826.,
#        1825., 1823., 1822., 1819., 1818., 1817., 1816., 1815., 1812.,
#        1811., 1810., 1808., 1807., 1805., 1804., 1803., 1802., 1801.,
#        1800., 1797., 1792., 1791., 1788., 1787., 1786., 1785., 1784.,
#        1783., 1780., 1779., 1776., 1771., 1767., 1764., 1758., 1753.,
#        1751., 1749., 1755., 1748., 1742., 1738., 1733., 1723., 1721.,
#        1703., 1700., 1642., 1691., 1640., 1638., 1637., 1617., 1595.,
#        1580., 1555., 1554., 1543., 1518., 1500., 1000.,   77.,    5.,
#           0.])

# %%
pd.NA  # The concept of a problem

# %%
sharks.notna().sum()
# Out:
# date              7012
# year              7010
# type              6994
# country           6962
# state             6527
# location          6446
# activity          6427
# name              6793
# sex               6433
# age               4018
# injury            6977
# fatal y/n         6451
# time              3486
# species           3881
# source            6993
# href formula      6794
# href              6796
# case number       6798
# case number.1     6797
# original order    6799
# unnamed: 21          1
# unnamed: 22          2
# dtype: int64

# %%
sharks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7012 entries, 0 to 7011
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            7012 non-null   object
#  1   year            7010 non-null   float64
#  2   type            6994 non-null   object
#  3   country         6962 non-null   object
#  4   state           6527 non-null   object
#  5   location        6446 non-null   object
#  6   activity        6427 non-null   object
#  7   name            6793 non-null   object
#  8   sex             6433 non-null   object
#  9   age             4018 non-null   object
#  10  injury          6977 non-null   object
#  11  fatal y/n       6451 non-null   object
#  12  time            3486 non-null   object
#  13  species         3881 non-null   object
#  14  source          6993 non-null   object
#  15  href formula    6794 non-null   object
#  16  href            6796 non-null   object
#  17  case number     6798 non-null   object
#  18  case number.1   6797 non-null   object
#  19  original order  6799 non-null   float64
#  20  unnamed: 21     1 non-null      object
#  21  unnamed: 22     2 non-null      object
# dtypes: float64(2), object(20)
# memory usage: 1.2+ MB

# %%
sharks["number_of_children"].fillna()
# Out:
#              date    year        type             country  \
# 202   25-Sep-2022  2022.0  Unprovoked        SOUTH AFRICA
# 205   03-Sep-2022  2022.0  Unprovoked                 USA
# 206   31-Aug-2022  2022.0  Unprovoked           AUSTRALIA
# 207   17-Aug-2022  2022.0  Unprovoked           AUSTRALIA
# 208   15-Aug-2022  2022.0  Unprovoked                 USA
# ...           ...     ...         ...                 ...
# 7006  Before 1906     0.0  Unprovoked           AUSTRALIA
# 7007  Before 1903     0.0  Unprovoked           AUSTRALIA
# 7008  Before 1903     0.0  Unprovoked           AUSTRALIA
# 7009    1900-1905     0.0  Unprovoked                 USA
# 7011    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                       state                             location  \
# 202   Western Cape Province       Central Beach, Plettenberg Bay
# 205                  Hawaii          Lower Paia Beach Park, Maui
# 206         New South Wales                                Avoca
# 207         New South Wales                        Coffs Harbour
# 208          South Carolina           Myrtle Beach, Horry County
# ...                     ...                                  ...
# 7006        New South Wales
# 7007      Western Australia                          Roebuck Bay
# 7008      Western Australia                                  NaN
# 7009         North Carolina                       Ocracoke Inlet
# 7011       Eastern Province  Below the English fort, Trincomalee
#
#                      activity                   name sex  age  ...   time  \
# 202                  Swimming          Kimon Bisogno   F   39  ...  07h53
# 205   Swimming  or Snorkeling                 female   F   51  ...  16h10
# 206                   Surfing             Sunni Pace   M   14  ...  07h00
# 207                  Kayaking           John Vincent   M  NaN  ...    NaN
# 208                  Swimming                 female   F  NaN  ...  11h17
# ...                       ...                    ...  ..  ...  ...    ...
# 7006                 Swimming               Arab boy   M  NaN  ...    NaN
# 7007                   Diving                   male   M  NaN  ...    NaN
# 7008             Pearl diving                  Ahmun   M  NaN  ...    NaN
# 7009                 Swimming  Coast Guard personnel   M  NaN  ...    NaN
# 7011                 Swimming                   male   M   15  ...    NaN
#
#                                                species   \
# 202                                    White shark, 13'
# 205                                                 NaN
# 206                                       Bronze whaler
# 207                                    White shark, 3 m
# 208                                                 NaN
# ...                                                 ...
# 7006  Said to involve a grey nurse shark that leapt ...
# 7007                                                NaN
# 7008                                                NaN
# 7009                                                NaN
# 7011                                                NaN
#
#                                                  source  \
# 202                                   Mirror, 9/25/2022
# 205                           Star Advertiser, 9/3/2022
# 206                                  Surfline, 9/2/2022
# 207                                      A Currie. GSAF
# 208                                   C. Creswell, GSAF
# ...                                                 ...
# 7006  L. Becke in New York Sun, 9/9/1906; L. Schultz...
# 7007                   H. Taunton; N. Bartlett,  p. 234
# 7008              H. Taunton; N. Bartlett,  pp. 233-234
# 7009               F. Schwartz, p.23; C. Creswell, GSAF
# 7011                                         S.W. Baker
#
#                                            href formula  \
# 202   http://sharkattackfile.net/spreadsheets/pdf_di...
# 205   http://sharkattackfile.net/spreadsheets/pdf_di...
# 206   http://sharkattackfile.net/spreadsheets/pdf_di...
# 207   http://sharkattackfile.net/spreadsheets/pdf_di...
# 208   http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 7006  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7007  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7008  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7009  http://sharkattackfile.net/spreadsheets/pdf_di...
# 7011  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href   case number  \
# 202   http://sharkattackfile.net/spreadsheets/pdf_di...    2022.09.25
# 205   http://sharkattackfile.net/spreadsheets/pdf_di...    2022.09.03
# 206   http://sharkattackfile.net/spreadsheets/pdf_di...    2022.08.31
# 207   http://sharkattackfile.net/spreadsheets/pdf_di...    2022.08.17
# 208   http://sharkattackfile.net/spreadsheets/pdf_di...  2022.08.15.c
# ...                                                 ...           ...
# 7006  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0006
# 7007  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0005
# 7008  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0004
# 7009  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0003
# 7011  http://sharkattackfile.net/spreadsheets/pdf_di...       ND.0001
#
#      case number.1 original order unnamed: 21  unnamed: 22
# 202     2022.09.25         6802.0         NaN          NaN
# 205     2022.09.03         6800.0         NaN          NaN
# 206     2022.08.31         6799.0         NaN          NaN
# 207     2022.08.17         6798.0         NaN          NaN
# 208   2022.08.15.c         6797.0         NaN          NaN
# ...            ...            ...         ...          ...
# 7006       ND.0006            7.0         NaN          NaN
# 7007       ND.0005            6.0         NaN          NaN
# 7008       ND.0004            5.0         NaN          NaN
# 7009       ND.0003            4.0         NaN          NaN
# 7011       ND.0001            2.0         NaN          NaN
#
# [6319 rows x 22 columns]

# %%
pd.
