# %% [markdown]
# # Anomaly Detection
#
# This notebook explores outliers in a dataset of gym users.
#
# ## Imports

# %%
import pandas as pd
import altair as alt
import numpy as np
from scipy.stats import zscore

# %% [markdown]
# ## Data Sourcing

# %%
users = pd.read_csv("gym_unclean.csv")

# %%
users.head()
# Out:
#    Age  Gender  Weight (kg)  Height (m)  Avg_BPM  Session_Duration (hours)  \
# 0   53  Female         73.5        1.55      153                      1.17
# 1   47  Female         43.4        1.62      132                      0.51
# 2   18  Female         64.8        1.53      141                      1.98
# 3   37  Female         55.6        1.57      123                      0.97
# 4   40    Male         68.9        1.99      149                      1.16
#
#    Calories_Burned Workout_Type    BMI
# 0            806.0         HIIT  30.59
# 1            303.0       Cardio  16.54
# 2           1396.0        Ykoga  27.68
# 3            597.0       Cardio  22.56
# 4            951.0          NaN  17.40

# %% [markdown]
# ## Pre-Work questions
#
# 1. What are the oldest and youngest ages in the dataset?

# %%
users["Age"].min(), users["Age"].max()
# Out:
# (np.int64(-168), np.int64(248))

# %% [markdown]
# 2. What is the average weight?

# %%
print(users["Weight (kg)"].median())  # Less sensitive to outliers
print(users["Weight (kg)"].mean())
print(users["Weight (kg)"].mode())  # Most common
# Out:
# 69.80000000000001
# 131.1746223564955
# 0    57.7
# Name: Weight (kg), dtype: float64

# %% [markdown]
# 3. How many rows are in the data?

# %%
users.shape[0]
# Out:
# 1324

# %% [markdown]
# 4. What is the second largest BMI in the dataset?

# %%
users["BMI"].sort_values(ascending=False).nlargest(2)
# Out:
# 1122    49.84
# 292     48.43
# Name: BMI, dtype: float64

# %% [markdown]
# ## Anomaly Detection

# %%
users.describe()
# Out:
#                Age   Weight (kg)   Height (m)      Avg_BPM  \
# count  1324.000000   1324.000000  1324.000000  1324.000000
# mean     38.486405    131.174622     1.723165   143.861782
# std      22.602530    679.087829     0.129968    14.356799
# min    -168.000000     40.000000     1.500000   120.000000
# 25%      28.000000     58.200000     1.620000   132.000000
# 50%      39.000000     69.800000     1.710000   143.000000
# 75%      50.000000     86.200000     1.810000   157.000000
# max     248.000000  10790.000000     2.000000   169.000000
#
#        Session_Duration (hours)  Calories_Burned          BMI
# count               1324.000000      1129.000000  1324.000000
# mean                   1.332509       908.844996    24.868104
# std                    1.051352       270.076680     6.587098
# min                    0.024549       303.000000    12.320000
# 25%                    1.030000       723.000000    20.190000
# 50%                    1.260000       895.000000    24.175000
# 75%                    1.470000      1081.000000    28.490000
# max                   26.453492      1783.000000    49.840000

# %%
a = [1, 3.5, 1, 1, 1]
print(np.mean(a))
print(np.std(a))
print(zscore(a))
# Out:
# 1.5
# 1.0
# [-0.5  2.  -0.5 -0.5 -0.5]

# %%
zscore([1, 1, 2, 1])
# Out:
# array([-0.57735027, -0.57735027,  1.73205081, -0.57735027])

# %%
users["Age"].quantile(0.25)
# Out:
# np.float64(28.0)

# %% [markdown]
# ## Anomaly Detection

# %%
users.describe()
# Out:
#                Age   Weight (kg)   Height (m)      Avg_BPM  \
# count  1324.000000   1324.000000  1324.000000  1324.000000
# mean     38.486405    131.174622     1.723165   143.861782
# std      22.602530    679.087829     0.129968    14.356799
# min    -168.000000     40.000000     1.500000   120.000000
# 25%      28.000000     58.200000     1.620000   132.000000
# 50%      39.000000     69.800000     1.710000   143.000000
# 75%      50.000000     86.200000     1.810000   157.000000
# max     248.000000  10790.000000     2.000000   169.000000
#
#        Session_Duration (hours)  Calories_Burned          BMI
# count               1324.000000      1129.000000  1324.000000
# mean                   1.332509       908.844996    24.868104
# std                    1.051352       270.076680     6.587098
# min                    0.024549       303.000000    12.320000
# 25%                    1.030000       723.000000    20.190000
# 50%                    1.260000       895.000000    24.175000
# 75%                    1.470000      1081.000000    28.490000
# max                   26.453492      1783.000000    49.840000

# %% [markdown]
# Quantile: a division of the data with an equal number of data points to comparable
# Standard deviation (std) : how far stuff is spread away from the mean

# %%
users[(users["Age"] > users["Age"].quantile(0.05)) & (users["Age"] > users["Age"].quantile(0.95))]
# Out:
#       Age  Gender  Weight (kg)  Height (m)  Avg_BPM  Session_Duration (hours)  \
# 12     58  Female         56.5        1.70      122                      0.74
# 16     59    Male         85.5        1.67      144                      1.99
# 32     58    Male         82.2        1.87      143                      1.57
# 61    248    Male         87.5        1.88      134                      1.19
# 75     58  Female         63.0        1.78      154                      1.58
# ...   ...     ...          ...         ...      ...                       ...
# 1214   59  Female         42.1        1.65      132                      1.22
# 1239   58    Male         74.6        1.75      137                      1.09
# 1250  157  Female         78.0        1.68      135                      1.29
# 1258   58  Female         65.2        1.63      121                      1.12
# 1322   59  Female         70.7        1.68      121                      1.17
#
#       Calories_Burned Workout_Type    BMI
# 12              406.0          NaN  19.55
# 16             1418.0       Cradio  30.66
# 32             1111.0         HIIT  23.51
# 61              789.0         Yoga  24.76
# 75             1095.0         HIIT  19.88
# ...               ...          ...    ...
# 1214            725.0     Strength  15.46
# 1239            739.0         HIIT  24.36
# 1250            871.0         HIIT  27.64
# 1258            610.0         HIIT  24.54
# 1322            637.0       Cardio  25.05
#
# [67 rows x 9 columns]

# %%
users["age_z"] = zscore(users["Age"])

# %%
users[users["age_z"] > 3]
# Out:
#       Age  Gender  Weight (kg)  Height (m)  Avg_BPM  Session_Duration (hours)  \
# 61    248    Male         87.5        1.88      134                      1.19
# 407   140  Female         46.6        1.50      165                      1.38
# 539   226    Male         64.5        1.79      130                      1.17
# 595   204  Female         69.6        1.58      135                      1.49
# 604   172  Female         59.1        1.72      148                      1.07
# 676   203    Male         82.5        1.79      139                      1.69
# 856   110    Male         87.6        1.93      139                      1.72
# 1034  211    Male         47.1        1.78      149                      1.26
# 1250  157  Female         78.0        1.68      135                      1.29
#
#       Calories_Burned Workout_Type    BMI     age_z
# 61              789.0         Yoga  24.76  9.272978
# 407            1025.0     Strength  20.71  4.492946
# 539             753.0         Yoga  20.13  8.299268
# 595            1006.0       Cardio  27.88  7.325558
# 604             792.0       Cardio  19.98  5.909252
# 676            1163.0       Cardio  25.75  7.281298
# 856            1315.0         HIIT  23.52  3.165160
# 1034            929.0         Yoga  14.87  7.635375
# 1250            871.0         HIIT  27.64  5.245359

# %% [markdown]
# ## Visual

# %%
alt.Chart(users).mark_boxplot().encode(
    x="Age",
    y="Gender",
    tooltip=["Age", "Gender"]
).properties(
    height=200,
    width=500
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(users).mark_point().encode(
    x=alt.X("Height (m)").scale(zero=False),
    y="Weight (kg)"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Cleaning

# %%
users = users[(users["Age"] > 0) & (users["Age"] < 117)]
users = users[zscore(users["Weight (kg)"]) < 3]
users = users[zscore(users["Height (m)"]) < 3]

# %%
users
# Out:
#       Age  Gender  Weight (kg)  Height (m)  Avg_BPM  Session_Duration (hours)  \
# 0      53  Female         73.5        1.55      153                      1.17
# 1      47  Female         43.4        1.62      132                      0.51
# 2      18  Female         64.8        1.53      141                      1.98
# 3      37  Female         55.6        1.57      123                      0.97
# 4      40    Male         68.9        1.99      149                      1.16
# ...   ...     ...          ...         ...      ...                       ...
# 1319   20    Male         55.0        1.60      168                      1.12
# 1320   31    Male         86.6        1.76      151                      1.29
# 1321   18  Female         72.7        1.55      125                      0.84
# 1322   59  Female         70.7        1.68      121                      1.17
# 1323   18    Male         70.0        1.61      168                      1.30
#
#       Calories_Burned Workout_Type    BMI     age_z
# 0               806.0         HIIT  30.59  0.642365
# 1               303.0       Cardio  16.54  0.376808
# 2              1396.0        Ykoga  27.68 -0.906719
# 3               597.0       Cardio  22.56 -0.065788
# 4               951.0          NaN  17.40  0.066991
# ...               ...          ...    ...       ...
# 1319           1035.0          NaN  21.48 -0.818200
# 1320           1071.0     Strength  27.96 -0.331345
# 1321            525.0          NaN  30.26 -0.906719
# 1322            637.0       Cardio  25.05  0.907923
# 1323           1201.0          NaN  27.01 -0.906719
#
# [1291 rows x 10 columns]

# %%
alt.Chart(users).mark_point().encode(
    x=alt.X("Height (m)").scale(zero=False),
    y="Weight (kg)"
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(users).mark_boxplot().encode(
    x="Calories_Burned",
    y="Gender",
).properties(
    height=200,
    width=500
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(users).mark_point().encode(
    x="Calories_Burned",
    y="Session_Duration (hours)",
    color="Workout_Type",
    tooltip=["Calories_Burned", "Session_Duration (hours)", "Workout_Type"]
)
# Out:
# alt.Chart(...)
